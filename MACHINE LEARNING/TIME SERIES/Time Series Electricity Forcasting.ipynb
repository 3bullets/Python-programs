# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
#from pandas import DataFrame

# %%
x = [
    950,
    875,
    968,
    919,
    1016,
    969,
    1042,
    1049,1004,1040,1005,1017,1006,943,1058,1026,1083,1050,1098,1095,1057,1097,1067,
    1066,1086,1028,1107,1075,1125,1120,1150,1160,1106,1089,1117,1130,1140,1035,1145,
    1130,1202,1174,1201,1210,1149,1167,1104,1138,1178,1071,1164,1159,1253,1273,1282,
    1279,1287,1372,1300,1362,1370,1311,1422,1296,1413,1380,1410,1375,1349,1369,1350,
    1357,1283,1252,1328,1341,1426,1412,1500,1486,1424,1453,1224,1212,1218,1111,1300,
    1267,1381,1325,1387,1390,1448,1468,1394,1419,1477,1374,1541,1455,1543,1512,1527,
    1499,1513,1575,1523,1540,1545,1450,1598,1507,1584,1571,1458,1428,1617,1668,1622,
    1605,1604,1583,1568,1450,1524,1494,1497,1500,1529,1554,1547,1502,1471,1367,1476,
    1445,1504,1588,1674,1664,1672,1647,1580,1605,1604,1444,1562,1582,1645,1647,1707,
    1691,1686,1746,1707,1734,1709,1551,1649,1619,1698,1643,1610,1599,1660,1776,1682,
    1668,1705,1653,1682,1669,1681,1595,1595,1618,1588,1668,1582,1614,1633,1491,1679,
    1605,1691,1584,1549,1545,1547,1671,1657,1701,1724,1559,1762,1702,1773,1653,1709,
    1657,1707,1832,1779,1760,1776,1635,1757,1728,1805,1697,1678,1633,1697,1794,1736,
    1718,1730,1633,1661,1189,1566,1618,1678,1677,1690,1785,1701,1745,1735,1585,1763,
    1737,1805,1675,1749,1719,1734,1746,1735,1742

]

# %%
y =  "MO012002,MO022002,MO032002,MO042002,MO052002,MO062002,MO072002,MO082002,MO092002,MO102002,MO112002,MO122002,MO012003,MO022003,MO032003,MO042003,MO052003,MO062003,MO072003,MO082003,MO092003,MO102003,MO112003,MO122003,MO012004,MO022004,MO032004,MO042004,MO052004,MO062004,MO072004,MO082004,MO092004,MO102004,MO112004,MO122004,MO012005,MO022005,MO032005,MO042005,MO052005,MO062005,MO072005,MO082005,MO092005,MO102005,MO112005,MO122005,MO012006,MO022006,MO032006,MO042006,MO052006,MO062006,MO072006,MO082006,MO092006,MO102006,MO112006,MO122006,MO012007,MO022007,MO032007,MO042007,MO052007,MO062007,MO072007,MO082007,MO092007,MO102007,MO112007,MO122007,MO012008,MO022008,MO032008,MO042008,MO052008,MO062008,MO072008,MO082008,MO092008,MO102008,MO112008,MO122008,MO012009,MO022009,MO032009,MO042009,MO052009,MO062009,MO072009,MO082009,MO092009,MO102009,MO112009,MO122009,MO012010,MO022010,MO032010,MO042010,MO052010,MO062010,MO072010,MO082010,MO092010,MO102010,MO112010,MO122010,MO012011,MO022011,MO032011,MO042011,MO052011,MO062011,MO072011,MO082011,MO092011,MO102011,MO112011,MO122011,MO012012,MO022012,MO032012,MO042012,MO052012,MO062012,MO072012,MO082012,MO092012,MO102012,MO112012,MO122012,MO012013,MO022013,MO032013,MO042013,MO052013,MO062013,MO072013,MO082013,MO092013,MO102013,MO112013,MO122013,MO012014,MO022014,MO032014,MO042014,MO052014,MO062014,MO072014,MO082014,MO092014,MO102014,MO112014,MO122014,MO012015,MO022015,MO032015,MO042015,MO052015,MO062015,MO072015,MO082015,MO092015,MO102015,MO112015,MO122015,MO012016,MO022016,MO032016,MO042016,MO052016,MO062016,MO072016,MO082016,MO092016,MO102016,MO112016,MO122016,MO012017,MO022017,MO032017,MO042017,MO052017,MO062017,MO072017,MO082017,MO092017,MO102017,MO112017,MO122017,MO012018,MO022018,MO032018,MO042018,MO052018,MO062018,MO072018,MO082018,MO092018,MO102018,MO112018,MO122018,MO012019,MO022019,MO032019,MO042019,MO052019,MO062019,MO072019,MO082019,MO092019,MO102019,MO112019,MO122019,MO012020,MO022020,MO032020,MO042020,MO052020,MO062020,MO072020,MO082020,MO092020,MO102020,MO112020,MO122020,MO012021,MO022021,MO032021,MO042021,MO052021,MO062021,MO072021,MO082021,MO092021,MO102021,MO112021,MO122021"

# %%
i = y.split(",")

# %%
i
# Out:
# ['MO012002',
#  'MO022002',
#  'MO032002',
#  'MO042002',
#  'MO052002',
#  'MO062002',
#  'MO072002',
#  'MO082002',
#  'MO092002',
#  'MO102002',
#  'MO112002',
#  'MO122002',
#  'MO012003',
#  'MO022003',
#  'MO032003',
#  'MO042003',
#  'MO052003',
#  'MO062003',
#  'MO072003',
#  'MO082003',
#  'MO092003',
#  'MO102003',
#  'MO112003',
#  'MO122003',
#  'MO012004',
#  'MO022004',
#  'MO032004',
#  'MO042004',
#  'MO052004',
#  'MO062004',
#  'MO072004',
#  'MO082004',
#  'MO092004',
#  'MO102004',
#  'MO112004',
#  'MO122004',
#  'MO012005',
#  'MO022005',
#  'MO032005',
#  'MO042005',
#  'MO052005',
#  'MO062005',
#  'MO072005',
#  'MO082005',
#  'MO092005',
#  'MO102005',
#  'MO112005',
#  'MO122005',
#  'MO012006',
#  'MO022006',
#  'MO032006',
#  'MO042006',
#  'MO052006',
#  'MO062006',
#  'MO072006',
#  'MO082006',
#  'MO092006',
#  'MO102006',
#  'MO112006',
#  'MO122006',
#  'MO012007',
#  'MO022007',
#  'MO032007',
#  'MO042007',
#  'MO052007',
#  'MO062007',
# ...

# %%
frame = {
    "date": i,
    "electricity": x,
}

# %%
new = pd.DataFrame.from_dict(frame)

# %%
new.head()
# Out:
#        date  electricity
# 0  MO012002          950
# 1  MO022002          875
# 2  MO032002          968
# 3  MO042002          919
# 4  MO052002         1016

# %%
new.to_csv('time_series.csv')

# %%
new['date'] = new['date'].str.replace(r'\D', '')
# Out:
# C:\Users\tebel\AppData\Local\Temp\ipykernel_13012\2906418610.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   new['date'] = new['date'].str.replace(r'\D', '')

# %%
new.head()
# Out:
#      date  electricity
# 0  012002          950
# 1  022002          875
# 2  032002          968
# 3  042002          919
# 4  052002         1016

# %%
new.to_csv('series.csv')

# %%
df = new
print(df.head())
df['date'] = pd.to_datetime(df['date'], format='%m%Y')
df.head()
# Out:
#      date  electricity
# 0  012002          950
# 1  022002          875
# 2  032002          968
# 3  042002          919
# 4  052002         1016
#         date  electricity
# 0 2002-01-01          950
# 1 2002-02-01          875
# 2 2002-03-01          968
# 3 2002-04-01          919
# 4 2002-05-01         1016

# %%
df.head(30)
# Out:
#          date  electricity
# 0  2002-01-01          950
# 1  2002-02-01          875
# 2  2002-03-01          968
# 3  2002-04-01          919
# 4  2002-05-01         1016
# 5  2002-06-01          969
# 6  2002-07-01         1042
# 7  2002-08-01         1049
# 8  2002-09-01         1004
# 9  2002-10-01         1040
# 10 2002-11-01         1005
# 11 2002-12-01         1017
# 12 2003-01-01         1006
# 13 2003-02-01          943
# 14 2003-03-01         1058
# 15 2003-04-01         1026
# 16 2003-05-01         1083
# 17 2003-06-01         1050
# 18 2003-07-01         1098
# 19 2003-08-01         1095
# 20 2003-09-01         1057
# 21 2003-10-01         1097
# 22 2003-11-01         1067
# 23 2003-12-01         1066
# 24 2004-01-01         1086
# 25 2004-02-01         1028
# 26 2004-03-01         1107
# 27 2004-04-01         1075
# 28 2004-05-01         1125
# 29 2004-06-01         1120

# %%
df.to_csv('data.csv')

# %%
df = pd.read_csv('data.csv',index_col=0)
df.head()
# Out:
#          date  electricity
# 0  2002-01-01          950
# 1  2002-02-01          875
# 2  2002-03-01          968
# 3  2002-04-01          919
# 4  2002-05-01         1016

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df["date"] = df["date"].astype("datetime64")

# %%
df = df.set_index("date")

# %%
df.head(20)
# Out:
#             electricity
# date
# 2002-01-01          950
# 2002-02-01          875
# 2002-03-01          968
# 2002-04-01          919
# 2002-05-01         1016
# 2002-06-01          969
# 2002-07-01         1042
# 2002-08-01         1049
# 2002-09-01         1004
# 2002-10-01         1040
# 2002-11-01         1005
# 2002-12-01         1017
# 2003-01-01         1006
# 2003-02-01          943
# 2003-03-01         1058
# 2003-04-01         1026
# 2003-05-01         1083
# 2003-06-01         1050
# 2003-07-01         1098
# 2003-08-01         1095

# %%
df.to_csv('final.csv')

# %%
df.head(3)
# Out:
#             electricity
# date
# 2002-01-01          950
# 2002-02-01          875
# 2002-03-01          968

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Import Library

import matplotlib.pyplot as plt

# Plot
plt.rcParams["figure.figsize"] = (16,6)
plt.plot(df["electricity"])

# Labelling 

plt.xlabel("Date")
plt.ylabel("Electricity")
plt.title("Pandas Time Series Plot")

# Display

plt.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
#series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0)
plt.rcParams["figure.figsize"] = (10,6)
plot_acf(df)
pyplot.show()

# %%
acf_plot = plot_acf(df, lags=100)

# %%
pacf_plot = plot_pacf(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 pacf_plot = plot_pacf(df)
#
# NameError: name 'plot_pacf' is not defined

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf
#series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0)
plt.rcParams["figure.figsize"] = (10,6)
plot_pacf(df)

pyplot.show()
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.stattools import adfuller

# %%
fuller_test = adfuller(df['electricity'])
fuller_test
# Out:
# (-1.7297119086659505,
#  0.41587266445489285,
#  14,
#  225,
#  {'1%': -3.4597521044060353,
#   '5%': -2.874472927517147,
#   '10%': -2.5736628197530864},
#  2486.274540582969)

# %%
def test_p_value(data):
        fuller_test = adfuller(data)
        print('P-value: ',fuller_test[1])
        if fuller_test[1] <= 0.05:
            print('Reject null hypothesis, data is stationary')
        else:
            print('Do not reject null hypothesis, data is not stationary')
test_p_value(df['electricity'])
# Out:
# P-value:  0.41587266445489285
# Do not reject null hypothesis, data is not stationary

# %%
df['First_diff'] = df['electricity'] - df['electricity'].shift(1)
plt.rcParams["figure.figsize"] = (10,6)
df['First_diff'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df['Seasonal_diff'] = df['electricity'] - df['electricity'].shift(12)
plt.rcParams["figure.figsize"] = (10,6)
df['Seasonal_diff'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
test_p_value(df['Seasonal_diff'].dropna())
# Out:
# P-value:  0.004037242229095776
# Reject null hypothesis, data is stationary

# %%
fuller_test = adfuller(df['First_diff'].dropna())
fuller_test
# Out:
# (-4.511430272033318,
#  0.00018749697132639762,
#  13,
#  225,
#  {'1%': -3.4597521044060353,
#   '5%': -2.874472927517147,
#   '10%': -2.5736628197530864},
#  2477.1892647403024)

# %%
fuller_test = adfuller(df['Seasonal_diff'].dropna())
fuller_test
# Out:
# (-3.705442955602977,
#  0.004037242229095776,
#  12,
#  215,
#  {'1%': -3.461136478222043,
#   '5%': -2.875078880098608,
#   '10%': -2.5739861168199027},
#  2380.0617952233465)

# %%
df.head()
# Out:
#             electricity  First_diff  Seasonal_diff
# date
# 2002-01-01          950         NaN            NaN
# 2002-02-01          875       -75.0            NaN
# 2002-03-01          968        93.0            NaN
# 2002-04-01          919       -49.0            NaN
# 2002-05-01         1016        97.0            NaN

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams["figure.figsize"] = (10,6)
first_diff = plot_acf(df['First_diff'].dropna())

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams["figure.figsize"] = (10,6)
first_diff = plot_pacf(df['First_diff'].dropna())
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
test_p_value(df['First_diff'].dropna())
# Out:
# P-value:  0.00018749697132639762
# Reject null hypothesis, data is stationary

# %%
plt.rcParams["figure.figsize"] = (10,6)
p1 = plot_acf(df['Seasonal_diff'].dropna())
p2 = plot_pacf(df['Seasonal_diff'].dropna())
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
df['Seasonal_diff'] = df['Production'] - df['Production'].shift(12)
df['Seasonal_diff'].plot()

# %%
test_p_value(df['Second_diff'].dropna())

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
plt.rcParams["figure.figsize"] = (10,6)
df['prediction'] = results.predict()
df[['electricity','prediction']].plot(figsize=(12,8))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
plt.rcParams["figure.figsize"] = (10,6)
decomposition = seasonal_decompose(df['electricity'], 
                                   model='multiplicative', 
                                   period=12)
decomposition.plot();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
plt.rcParams["figure.figsize"] = (10,6)
decomposition = seasonal_decompose(df['electricity'], 
                                   model='multiplicative', 
                                   period=12)
decomposition.plot();

# %%
r = pd.read_csv("final.csv")
r.head(3)

# %%
df.describe()
# Out:
#        electricity  First_diff  Seasonal_diff
# count   240.000000  239.000000     228.000000
# mean   1456.195833    3.313808      38.907895
# std     243.368772   80.744578     101.355376
# min     875.000000 -472.000000    -539.000000
# 25%    1271.500000  -34.000000     -15.500000
# 50%    1523.500000    3.000000      49.500000
# 75%    1665.000000   51.500000      90.250000
# max    1832.000000  377.000000     548.000000

# %%
df.skew()
# Out:
# electricity     -0.554228
# First_diff      -0.408787
# Seasonal_diff   -0.312685
# dtype: float64

# %%
df.median()
# Out:
# electricity      1523.5
# First_diff          3.0
# Seasonal_diff      49.5
# dtype: float64

# %%
from statsmodels.tsa.stattools import acf

# %%
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# Out:
# date
# 2002-01-01     950
# 2002-02-01     875
# 2002-03-01     968
# 2002-04-01     919
# 2002-05-01    1016
#               ...
# 2008-09-01    1424
# 2008-10-01    1453
# 2008-11-01    1224
# 2008-12-01    1212
# 2009-01-01    1218
# Name: electricity, Length: 85, dtype: int64

# %%
# Out:
# date
# 2002-01-01     950
# 2002-02-01     875
# 2002-03-01     968
# 2002-04-01     919
# 2002-05-01    1016
#               ...
# 2021-08-01    1719
# 2021-09-01    1734
# 2021-10-01    1746
# 2021-11-01    1735
# 2021-12-01    1742
# Name: electricity, Length: 240, dtype: int64

# %%
df.shape
# Out:
# (240, 1)

# %% [markdown]
# # MODEL 1

# %%
model = sm.tsa.statespace.SARIMAX(df['electricity'],order=(1,1,1),seasonal_order=(1,0,1,12))
results = model.fit()
results.summary()
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                        electricity   No. Observations:                  240
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood               -1302.575
# Date:                            Sun, 06 Nov 2022   AIC                           2615.150
# Time:                                    21:32:52   BIC                           2632.533
# Sample:                                01-01-2002   HQIC                          2622.155
# ...

# %%
df['prediction'] = results.predict()
df[['electricity','prediction']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from pandas.tseries.offsets import DateOffset
extra_dates = [df.index[-1] + DateOffset(months=m) for m in range (1,24)]

# %%
extra_dates
# Out:
# [Timestamp('2022-01-01 00:00:00'),
#  Timestamp('2022-02-01 00:00:00'),
#  Timestamp('2022-03-01 00:00:00'),
#  Timestamp('2022-04-01 00:00:00'),
#  Timestamp('2022-05-01 00:00:00'),
#  Timestamp('2022-06-01 00:00:00'),
#  Timestamp('2022-07-01 00:00:00'),
#  Timestamp('2022-08-01 00:00:00'),
#  Timestamp('2022-09-01 00:00:00'),
#  Timestamp('2022-10-01 00:00:00'),
#  Timestamp('2022-11-01 00:00:00'),
#  Timestamp('2022-12-01 00:00:00'),
#  Timestamp('2023-01-01 00:00:00'),
#  Timestamp('2023-02-01 00:00:00'),
#  Timestamp('2023-03-01 00:00:00'),
#  Timestamp('2023-04-01 00:00:00'),
#  Timestamp('2023-05-01 00:00:00'),
#  Timestamp('2023-06-01 00:00:00'),
#  Timestamp('2023-07-01 00:00:00'),
#  Timestamp('2023-08-01 00:00:00'),
#  Timestamp('2023-09-01 00:00:00'),
#  Timestamp('2023-10-01 00:00:00'),
#  Timestamp('2023-11-01 00:00:00')]

# %%
forecast_df = pd.DataFrame(index=extra_dates,columns=df.columns)
forecast_df.head()
# Out:
#            electricity prediction
# 2022-01-01         NaN        NaN
# 2022-02-01         NaN        NaN
# 2022-03-01         NaN        NaN
# 2022-04-01         NaN        NaN
# 2022-05-01         NaN        NaN

# %%
df.shape
# Out:
# (240, 2)

# %%
final_df = pd.concat([df,forecast_df])

# %%
final_df['prediction'] = results.predict(start=239, end=430)
final_df[['electricity','prediction']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df.electricity, df.prediction)
mse
# Out:
# 6805.47841173634

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(df.electricity, df.prediction)
mae
# Out:
# 40.502495193780035

# %%
from math import sqrt
rmse = sqrt(mse)
rmse
# Out:
# 82.49532357495387

# %%
from sklearn.metrics import r2_score
r2 = r2_score(df.electricity, df.prediction)
r2
# Out:
# 0.8846168738306476

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(df.electricity, df.prediction)
mape
# Out:
# 0.030053210940428055

# %%
from sklearn.metrics import max_error
MaxAE = max_error(df.electricity, df.prediction)
MaxAE
# Out:
# 950.0

# %% [markdown]
# # MODEL 2

# %%
model2 = sm.tsa.statespace.SARIMAX(df['electricity'],order=(1,0,1),seasonal_order=(1,1,1,12))
results2 = model2.fit()
print(results2.summary())

df['prediction'] = results2.predict()
df[['electricity','prediction']].plot(figsize=(12,8))

#final_df['prediction'] = results2.predict(start=239, end=430)
#final_df[['electricity','prediction']].plot(figsize=(12,8))

mse = mean_squared_error(df.electricity, df.prediction)
print(f"mse: {mse}")

mae = mean_absolute_error(df.electricity, df.prediction)
print(f"mae: {mae}")

rmse = sqrt(mse)
print(f"rmse: {rmse}")

r2 = r2_score(df.electricity, df.prediction)
print(f"r2: {r2}")

mape = mean_absolute_percentage_error(df.electricity, df.prediction)
print(f"mape:{mape}")

MaxAE = max_error(df.electricity, df.prediction)
print(f"MaxAE: {MaxAE}")
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ...
# Dep. Variable:                        electricity   No. Observations:                  240
# Model:             SARIMAX(1, 0, 1)x(1, 1, 1, 12)   Log Likelihood               -1251.261
# Date:                            Fri, 28 Oct 2022   AIC                           2512.522
# ...

# %% [markdown]
# # MODEL 3

# %%
model3 = sm.tsa.statespace.SARIMAX(df['electricity'],order=(1,1,1),seasonal_order=(2,1,1,12))
results3 = model3.fit()
print(results3.summary())

df['prediction'] = results3.predict()
df[['electricity','prediction']].plot(figsize=(12,8))

#final_df['prediction'] = results3.predict(start=239, end=430)
#final_df[['electricity','prediction']].plot(figsize=(12,8))

mse = mean_squared_error(df.electricity, df.prediction)
print(f"mse: {mse}")

mae = mean_absolute_error(df.electricity, df.prediction)
print(f"mae: {mae}")

rmse = sqrt(mse)
print(f"rmse: {rmse}")

r2 = r2_score(df.electricity, df.prediction)
print(f"r2: {r2}")

mape = mean_absolute_percentage_error(df.electricity, df.prediction)
print(f"mape:{mape}")

MaxAE = max_error(df.electricity, df.prediction)
print(f"MaxAE: {MaxAE}")
# Out:
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\tebel\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# ...
# Dep. Variable:                        electricity   No. Observations:                  240
# Model:             SARIMAX(1, 1, 1)x(2, 1, 1, 12)   Log Likelihood               -1236.959
# Date:                            Sun, 06 Nov 2022   AIC                           2485.918
# Time:                                    21:37:04   BIC                           2506.468
# Sample:                                01-01-2002   HQIC                          2494.210
#                                      - 12-01-2021
# ...

# %%
from skforecast.model_selection import backtesting_forecaster
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 from skforecast.model_selection import backtesting_forecaster
#
# ModuleNotFoundError: No module named 'skforecast'

# %% [markdown]
# # HISTOGRAMS

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (11,8)
sns.histplot(results.resid);

# %%
residuals = results.resid

# %%
sns.histplot(data=residuals,  binwidth=30)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
residuals.head()
# Out:
# date
# 2002-01-01    950.000000
# 2002-02-01    -74.063592
# 2002-03-01     82.177969
# 2002-04-01    -42.066757
# 2002-05-01     93.685551
# dtype: float64

# %%
import statsmodels.api as sm
import pylab as py
  
# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code 
# the graph look different than shown below.
  
# Random data points generated
data_points = np.random.normal(0, 1, 100)    
  
sm.qqplot(residuals, line ='45')
py.show()

# %%
import scipy.stats as stats
#normal_sample = rvs.rvs(size=1000)
stats.probplot(residuals, dist="norm", plot=plt)
plt.show()

# %%
#residuals2 = results2.resid
residuals3 = results3.resid

# %%
stats.probplot(residuals2, dist="norm", plot=plt)
plt.show()

# %%
stats.probplot(residuals3, dist="norm", plot=plt)
plt.show()

# %%
a = sns.histplot(results.resid)
a.set(xlabel ="residuals", ylabel = "count", title ='Model 1')
plt.show()

# %%
b = sns.histplot(results2.resid)
b.set(xlabel ="residuals", ylabel = "count", title ='Model 2')
plt.show()

# %%
c = sns.histplot(results3.resid)
c.set(xlabel ="residuals", ylabel = "count", title ='Model 3')
plt.show()
